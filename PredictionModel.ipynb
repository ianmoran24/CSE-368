# %%
import yfinance as yf

# %%
dkng = yf.Ticker("DKNG")
dkng = dkng.history(period="max")
dkng
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2019-07-25 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# 2019-07-26 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# 2019-07-29 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# 2019-07-30 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# 2019-07-31 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# ...                              ...        ...        ...        ...
# 2024-11-01 00:00:00-04:00  35.509998  36.380001  35.419998  35.689999
# 2024-11-04 00:00:00-05:00  35.590000  36.252998  35.099998  35.689999
# 2024-11-05 00:00:00-05:00  35.759998  36.650002  35.700001  36.450001
# 2024-11-06 00:00:00-05:00  38.130001  38.715000  37.365002  38.250000
# 2024-11-07 00:00:00-05:00  38.709999  39.380001  38.299999  38.980000
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
del dkng["Dividends"]
del dkng["Stock Splits"]

# %%
dkng["Tomorrow"] = dkng["Close"].shift(-1)
dkng
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2019-07-25 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# 2019-07-26 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# 2019-07-29 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# 2019-07-30 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# 2019-07-31 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# ...                              ...        ...        ...        ...
# 2024-11-01 00:00:00-04:00  35.509998  36.380001  35.419998  35.689999
# 2024-11-04 00:00:00-05:00  35.590000  36.252998  35.099998  35.689999
# 2024-11-05 00:00:00-05:00  35.759998  36.650002  35.700001  36.450001
# 2024-11-06 00:00:00-05:00  38.130001  38.715000  37.365002  38.250000
# 2024-11-07 00:00:00-05:00  38.709999  39.380001  38.299999  38.980000
#
#                              Volume   Tomorrow
# Date
# 2019-07-25 00:00:00-04:00       100   9.800000
# ...

# %%
dkng["Target"] = (dkng["Tomorrow"] > dkng["Close"]).astype(int)
dkng
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2019-07-25 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# 2019-07-26 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# 2019-07-29 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# 2019-07-30 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# 2019-07-31 00:00:00-04:00   9.800000   9.800000   9.800000   9.800000
# ...                              ...        ...        ...        ...
# 2024-11-01 00:00:00-04:00  35.509998  36.380001  35.419998  35.689999
# 2024-11-04 00:00:00-05:00  35.590000  36.252998  35.099998  35.689999
# 2024-11-05 00:00:00-05:00  35.759998  36.650002  35.700001  36.450001
# 2024-11-06 00:00:00-05:00  38.130001  38.715000  37.365002  38.250000
# 2024-11-07 00:00:00-05:00  38.709999  39.380001  38.299999  38.980000
#
#                              Volume   Tomorrow  Target
# Date
# 2019-07-25 00:00:00-04:00       100   9.800000       0
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = dkng.iloc[:-100]
test = dkng.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
# from sklearn.metrics import precision_score

# preds = model.predict(test[predictors])
# preds

# from sklearn.metrics import precision_score

# preds = model.predict(test[predictors])
# preds = pd.Series(preds, index=test.index)
# precision_score(test["Target"], preds)

from sklearn.metrics import precision_score

preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["Target"], preds)
# Out:
# 0.5365853658536586

# %%
import pandas as pd

preds = pd.Series(preds, index=test.index)

# %%
preds
# Out:
# Date
# 2024-06-18 00:00:00-04:00    1
# 2024-06-20 00:00:00-04:00    0
# 2024-06-21 00:00:00-04:00    1
# 2024-06-24 00:00:00-04:00    1
# 2024-06-25 00:00:00-04:00    0
#                             ..
# 2024-11-01 00:00:00-04:00    1
# 2024-11-04 00:00:00-05:00    1
# 2024-11-05 00:00:00-05:00    1
# 2024-11-06 00:00:00-05:00    0
# 2024-11-07 00:00:00-05:00    0
# Length: 100, dtype: int64

# %%
precision_score(test["Target"], preds)
# Out:
# 0.5365853658536586

# %%
combined = pd.concat([test["Target"], preds], axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def testCase(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i] #had .copy here before
        test = data.iloc[i:(i+step)] #had .copy here before
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)

    return pd.concat(all_predictions)

# %%
predictions = testCasae(dkng, model, predictors)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-b3ac5c1c4f61> in <cell line: 1>()
# ----> 1 predictions = backtest(dkng, model, predictors)
#
# <ipython-input-133-9974c23f0b55> in backtest(data, model, predictors, start, step)
#       8         all_predictions.append(predictions)
#       9
# ---> 10     return pd.concat(all_predictions)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380         copy = False
#     381
# --> 382     op = _Concatenator(
#     383         objs,
#     384         axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     443         self.copy = copy
#     444
# ...

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    3659
# 1    2621
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5288057993132392

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.535669
# 0    0.464331
# Name: count, dtype: float64
